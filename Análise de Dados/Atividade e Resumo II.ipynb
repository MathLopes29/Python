# %%
import numpy as np
import pandas as pd
import seaborn as srn
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/co2.csv",sep = ',')
df
# Out:
#    Plant         Type   Treatment  conc  uptake
# 0    Qn1       Quebec  nonchilled    95    16.0
# 1    Qn1       Quebec  nonchilled   175    30.4
# 2    Qn1       Quebec  nonchilled   250    34.8
# 3    Qn1       Quebec  nonchilled   350    37.2
# 4    Qn1       Quebec  nonchilled   500    35.3
# ..   ...          ...         ...   ...     ...
# 79   Mc3  Mississippi     chilled   250    17.9
# 80   Mc3  Mississippi     chilled   350    17.9
# 81   Mc3  Mississippi     chilled   500    17.9
# 82   Mc3  Mississippi     chilled   675    18.9
# 83   Mc3  Mississippi     chilled  1000    19.9
#
# [84 rows x 5 columns]

# %%
df.head()
# Out:
#   Plant    Type   Treatment  conc  uptake
# 0   Qn1  Quebec  nonchilled    95    16.0
# 1   Qn1  Quebec  nonchilled   175    30.4
# 2   Qn1  Quebec  nonchilled   250    34.8
# 3   Qn1  Quebec  nonchilled   350    37.2
# 4   Qn1  Quebec  nonchilled   500    35.3

# %%
df.tail()
# Out:
#    Plant         Type Treatment  conc  uptake
# 79   Mc3  Mississippi   chilled   250    17.9
# 80   Mc3  Mississippi   chilled   350    17.9
# 81   Mc3  Mississippi   chilled   500    17.9
# 82   Mc3  Mississippi   chilled   675    18.9
# 83   Mc3  Mississippi   chilled  1000    19.9

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84 entries, 0 to 83
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Plant      84 non-null     object
#  1   Type       84 non-null     object
#  2   Treatment  84 non-null     object
#  3   conc       84 non-null     int64
#  4   uptake     84 non-null     float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 3.4+ KB

# %%
df.shape
# Out:
# (84, 5)

# %%
df.isnull().sum()
# Out:
# Plant        0
# Type         0
# Treatment    0
# conc         0
# uptake       0
# dtype: int64

# %%
df.groupby(df['Plant']).size()
# Out:
# Plant
# Mc1    7
# Mc2    7
# Mc3    7
# Mn1    7
# Mn2    7
# Mn3    7
# Qc1    7
# Qc2    7
# Qc3    7
# Qn1    7
# Qn2    7
# Qn3    7
# dtype: int64

# %%
#df.groupby(df['uptake']).size

# %%
x = df.conc
y = df.uptake

# %%
unicos = list(set(df.Treatment))
unicos
# Out:
# ['chilled', 'nonchilled']

# %%
for i in range(len(unicos)):
  indice = df.Treatment == unicos[i]
  plt.scatter(x[indice], y[indice], label = unicos[i])
plt.legend(loc="lower right")

# %%
srn.scatterplot(x=df.conc,y=df.uptake, data=df, hue=df.Treatment)
# Out:
# <Axes: xlabel='conc', ylabel='uptake'>

# %%
srn.catplot(x='conc', y='uptake', data=df, col='Treatment')

# %%
srn.histplot(df.iloc[:,3], kde=True, bins=6, color='darkred').set_title('Histograma')
# Out:
# Text(0.5, 1.0, 'Histograma')
