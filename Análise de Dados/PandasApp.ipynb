# %%
# Importanto as Bibliotecas - pip install pandas
import numpy as np
import pandas as pd

# Leitura dos Dados
df = pd.read_csv("https://pycourse.s3.amazonaws.com/temperature.csv",encoding = 'latin-1', sep = ',')

# Tamnaho
print("Tamanho",df.shape)

# Visualização das três primeiras linhas
print(df.head(3),"\n")

# Visualização das três últimas linhas
print(df.tail(3),'\n')
# Out:
# Tamanho (6, 3)
#          date  temperatura classification
# 0  2020-01-01         29.1         quente
# 1  2020-02-01         31.2   muito quente
# 2  2020-03-01         28.5         quente
#
#          date  temperatura classification
# 3  2020-04-01         28.0         quente
# 4  2020-05-01         24.0    confortavel
# 5  2020-06-01         20.0           frio

# %%
# Manipulando Estatísticas Básicas
df.describe()
# Out:
#        temperatura
# count     6.000000
# mean     26.800000
# std       4.075782
# min      20.000000
# 25%      25.000000
# 50%      28.250000
# 75%      28.950000
# max      31.200000

# %%
# Dataframe info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            6 non-null      object
#  1   temperatura     6 non-null      float64
#  2   classification  6 non-null      object
# dtypes: float64(1), object(2)
# memory usage: 272.0+ bytes

# %%
# Nomes das colunas
# df.columns = ['Data', 'Temperatura', 'Classificação']
# df

# %%
# Leitura de Planilha Excel
excel_file = pd.ExcelFile("https://pycourse.s3.amazonaws.com/temperature.xlsx")

type(excel_file)
# Out:
# pandas.io.excel._base.ExcelFile

# %%
# Leitura da Primeira Aba do Excel (Sheet1)
# Dados Numéricos com Separador Decimal = '.'

df2 = pd.read_excel(excel_file, sheet_name='Sheet1')
df2
# Out:
#         date  temperatura classification
# 0 2020-01-01         29.1         quente
# 1 2020-02-01         31.2   muito quente
# 2 2020-03-01         28.5         quente
# 3 2020-04-01         28.0         quente
# 4 2020-05-01         24.0    confortavel
# 5 2020-06-01         20.0           frio

# %%
# Segunda Aba (Sheet2)
df3 = pd.read_excel(excel_file, sheet_name='Sheet2', decimal=',')
df3
# Out:
#         date  temperatura classification
# 0 2020-01-01         29.1         quente
# 1 2020-02-01         31.2   muito quente
# 2 2020-03-01         28.5         quente
# 3 2020-04-01         28.0         quente
# 4 2020-05-01         24.0    confortavel
# 5 2020-06-01         20.0           frio

# %%
# Tipos de Dados
print(df.dtypes,'\n')
# Out:
# date               object
# temperatura       float64
# classification     object
# dtype: object

# %%
# help(df.iloc)

# %%
# Indexação por índice, Selecionando TODAS as linhas e Coluna 1 (Temperatura)
print(df.iloc[:,1],'\n')
# Out:
# 0    29.1
# 1    31.2
# 2    28.5
# 3    28.0
# 4    24.0
# 5    20.0
# Name: temperatura, dtype: float64

# %%
# Seleção Mútipla
df[['date','temperatura', 'classification']]
# Out:
#         date  temperatura classification
# 0 2020-01-01         29.1         quente
# 1 2020-02-01         31.2   muito quente
# 2 2020-03-01         28.5         quente
# 3 2020-04-01         28.0         quente
# 4 2020-05-01         24.0    confortavel
# 5 2020-06-01         20.0           frio

# %%
print(df.iloc[0:3, 0:3])
# Out:
#         date  temperatura classification
# 0 2020-01-01         29.1         quente
# 1 2020-02-01         31.2   muito quente
# 2 2020-03-01         28.5         quente

# %%
# Indexação Direta apenas por Nome
print(df.loc[:,'date'],'\n')
# Out:
# 0   2020-01-01
# 1   2020-02-01
# 2   2020-03-01
# 3   2020-04-01
# 4   2020-05-01
# 5   2020-06-01
# Name: date, dtype: datetime64[ns]

# %%
# Indexação Booleana
print(df[df['temperatura'] >= 25],'\n')
print(df.loc[df['classification'] == 'quente'],"\n")
print(df.loc[df['classification'] == 'quente', 'temperatura'],'\n')
#print(df.index >= '2020-03-01','\n')
#print(df.loc[df.index <= '2020-03-01', ['classification']],'\n')
#print(df.iloc[df.index <= '2020-03-01', [-1]],'\n')
# Out:
#         date  temperatura classification
# 0 2020-01-01         29.1         quente
# 1 2020-02-01         31.2   muito quente
# 2 2020-03-01         28.5         quente
# 3 2020-04-01         28.0         quente
#
#         date  temperatura classification
# 0 2020-01-01         29.1         quente
# 2 2020-03-01         28.5         quente
# 3 2020-04-01         28.0         quente
#
# 0    29.1
# 2    28.5
# 3    28.0
# Name: temperatura, dtype: float64

# %%
# Ordenação por Valor
print(df.sort_values(by='temperatura'),'\n')

# Ordenação por Índice
print(df.sort_index(ascending=False),'\n')

# Ordenação por Coluna
print(df.sort_values(by=['date', 'temperatura']),'\n')
print(df.sort_values(by='date', na_position="first"))
# Out:
#         date  temperatura classification
# 5 2020-06-01         20.0           frio
# 4 2020-05-01         24.0    confortavel
# 3 2020-04-01         28.0         quente
# 2 2020-03-01         28.5         quente
# 0 2020-01-01         29.1         quente
# 1 2020-02-01         31.2   muito quente
#
#         date  temperatura classification
# 5 2020-06-01         20.0           frio
# 4 2020-05-01         24.0    confortavel
# 3 2020-04-01         28.0         quente
# 2 2020-03-01         28.5         quente
# 1 2020-02-01         31.2   muito quente
# 0 2020-01-01         29.1         quente
#
#         date  temperatura classification
# 0 2020-01-01         29.1         quente
# 1 2020-02-01         31.2   muito quente
# 2 2020-03-01         28.5         quente
# 3 2020-04-01         28.0         quente
# 4 2020-05-01         24.0    confortavel
# 5 2020-06-01         20.0           frio
#
#         date  temperatura classification
# 0 2020-01-01         29.1         quente
# ...

# %%
# Conversão da coluna Date para DateTime
df['date'] = pd.to_datetime(df['date'])
df.dtypes
# Out:
# date              datetime64[ns]
# temperatura              float64
# classification            object
# dtype: object

# %%
# Set Index
df = df.set_index('date')
df

# Visualizando Index
print(df.index,'\n')
# Out:
# DatetimeIndex(['2020-01-01', '2020-02-01', '2020-03-01', '2020-04-01',
#                '2020-05-01', '2020-06-01'],
#               dtype='datetime64[ns]', name='date', freq=None)

# %%
# Plot .... Color Picker
df.plot(style='-o' , linewidth=2.5, color='red', figsize=(10,5), grid=True);
# df.plot(style='--' ,figsize=(10,5), grid=True);
# df.plot(style='-.' ,figsize=(10,5), grid=True);

# %%
# Plot de Barra
df['classification'].value_counts().plot.bar(figsize=(10,5), rot=0, color='green')
# Out:
# <Axes: xlabel='classification'>

# %%
df.plot(kind='bar', figsize=(10,5), rot=30);

# %%
# Plot de Pizza
df['classification'].value_counts().plot.pie (autopct='%1.1f%%', shadow=True, figsize=(10,7));

# %%
# Group By
print(df.groupby(by='classification').mean(), '\n')
print(df.groupby(by='classification').sum(), '\n')
# Out:
#                 temperatura
# classification
# confortavel       24.000000
# frio              20.000000
# muito quente      31.200000
# quente            28.533333
#
#                 temperatura
# classification
# confortavel            24.0
# frio                   20.0
# muito quente           31.2
# quente                 85.6

# %%
# Copy de uma DataFrame: evita compartilhamento de memória
df2 = df.copy()

# %%
# Drop Remoção de uma Coluna - Não Altera da DataFrame
df3 = df2.drop('temperatura', axis=1)

# %%
# Drop Remoção de uma Coluna - Altera da DataFrame
# df2.drop('temperatura', axis=1, implace=True)

# %%
# Evitar Compartilhamento de Memória Assim Alterando Dois Data Frames de Uma vez
df2 = df

# %%
df2.head()
# Out:
#             temperatura classification
# date
# 2020-01-01         29.1         quente
# 2020-02-01         31.2   muito quente
# 2020-03-01         28.5         quente
# 2020-04-01         28.0         quente
# 2020-05-01         24.0    confortavel

# %%
df3.head()
# Out:
#            classification
# date
# 2020-01-01         quente
# 2020-02-01   muito quente
# 2020-03-01         quente
# 2020-04-01         quente
# 2020-05-01    confortavel

# %%
data = {'animal':['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
        'age':[2.5, 3, 0.5, np.nan, 5, 2, 4.5, np.nan, 7, 3],
        'visits':[1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'priority':['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}

labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

df = pd.DataFrame(data = data, index = labels)
# df.dtypes
# df['animal'].value_counts()
# df.describe()

# df.loc[:, 'visits']
# df.iloc[:, -2]
# df['visits']

# df.sort_values(by='visits', ascending=False)
df.shape
df
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  2.0       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %%
# Set Index
df = df.set_index('animal')
df
# Out:
#         age  visits priority
# animal
# cat     2.5       1      yes
# cat     3.0       3      yes
# snake   0.5       2       no
# dog     NaN       3      yes
# dog     5.0       2       no
# cat     2.0       3       no
# snake   4.5       1       no
# cat     NaN       1      yes
# dog     7.0       2       no
# dog     3.0       1       no

# %%
# Plot de Barra
df['visits'].value_counts().plot.bar(figsize=(10,5), rot=0, color='blue')
# Out:
# <Axes: xlabel='visits'>

# %%
print(df.groupby(by='priority').mean(), '\n')
# Out:
#                age    visits
# priority
# no        3.666667  1.833333
# yes       2.750000  2.000000

# %%
# Plot de Barra
df['priority'].value_counts().plot.pie (autopct='%1.1f%%', shadow=True, figsize=(10,7));

# %%
df['visits'].value_counts().plot.pie (autopct='%1.1f%%', shadow=True, figsize=(10,7));

# %%
df['age'].value_counts().plot.pie (autopct='%1.1f%%', shadow=True, figsize=(10,7));
