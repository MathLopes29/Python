# %% [markdown]
# ![logo2.fw.png](attachment:logo2.fw.png)
# # Universidade dos Dados
# GitHub: http://www.github.com/unidados/
#
# Site de dicas: https://www.dataquest.io/blog/jupyter-notebook-tips-tricks-shortcuts/
#
# Curta a nossa página no Facebook e fique por dentro das atualizações: <a href=http://facebook.com/universidadedosdados>Universidade dos Dados</a>

# %% [markdown]
# ## Funções Built In

# %%
#Indexação - Converte a expressão em um vetor e retorna a posição de um caracter, indicado entre os colchetes.
print("Funções")
# Out:
# Funções

# %%
frase = 'Uma vez Flamengo, sempre Flamengo!'
frase[5]
# Out:
# 'e'

# %%
frase[5:]
# Out:
# 'ez Flamengo, sempre Flamengo!'

# %%
print(frase[5:10])
# Out:
# ez Fl

# %%
print(frase[::1])
print(frase[:])
print(frase[0:])
# Out:
# Uma vez Flamengo, sempre Flamengo!
# Uma vez Flamengo, sempre Flamengo!
# Uma vez Flamengo, sempre Flamengo!

# %%
print(frase[::2])
# Out:
# UavzFaeg,smr lmno

# %%
print(frase[::-1])
# Out:
# !ognemalF erpmes ,ognemalF zev amU

# %%
#find - Localiza a primeira ocorrencia de uma string dentro de uma expressão NAO INCLUSA A ULTIMA POSICAO

# %%
#Retorna -1 em caso de objeto nao encontrado
frase.find('acesso')
# Out:
# -1

# %%
frase.find('Flamengo')
# Out:
# 8

# %%
frase.find('Flamengo') + 2
# Out:
# 10

# %%
#Encontrando após a primeira ocorrencia. Basta adicionar um segundo parametro na função, que indica o início da busca

# %%
hino = "Uma vez Flamengo, sempre Flamengo!"

# %%
hino.find("Flamengo")
# Out:
# 8

# %%
hino.find("Flamengo",9)
# Out:
# 25

# %%
hino[25:]
# Out:
# 'Flamengo!'

# %%
#Algumas outras funções

# %%
hino.upper()
# Out:
# 'UMA VEZ FLAMENGO, SEMPRE FLAMENGO!'

# %%
hino.lower()
# Out:
# 'uma vez flamengo, sempre flamengo!'

# %%
print(hino.split())
print(hino)
# Out:
# ['Uma', 'vez', 'Flamengo,', 'sempre', 'Flamengo!']
# Uma vez Flamengo, sempre Flamengo!

# %%
hino.split('Flamengo')
# Out:
# ['Uma vez ', ', sempre ', '!']

# %%
hino.endswith('!')
# Out:
# True

# %%
hino.endswith('Flamengo')
# Out:
# False
