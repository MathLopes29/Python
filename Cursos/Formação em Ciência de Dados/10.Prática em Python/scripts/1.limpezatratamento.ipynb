# %% [markdown]
# Formação Cientista de Dados - Fernando Amaral e Jones Granatyr
# Limpeza e tratamento de Dados

# %% [markdown]
# # **VISUALIZAÇÃO**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as srn
import statistics  as sts

# Mediana - valores numericos = sts.median(df['nome_coluna']) EX: sts.median(dataset['Salario'])
# Moda - valores categoricos = VALOR QUE MAIS APARECE!

# %%
#importar dados
dataset = pd.read_csv("Churn.csv", sep=";")
#visulizar
dataset.head()
# Out:
#    X0   X1  X2        X3  X4  X4.1        X6  X7  X8  X9         X10  X11
# 0   1  619  RS  Feminino  42     2         0   1   1   1  10134888.0    1
# 1   2  608  SC  Feminino  41     1   8380786   1   0   1  11254258.0    0
# 2   3  502  RS  Feminino  42     8   1596608   3   1   0  11393157.0    1
# 3   4  699  RS  Feminino  39     1         0   2   0   0   9382663.0    0
# 4   5  850  SC  Feminino  43     2  12551082   1   1   1    790841.0    0

# %%
#tamanho
dataset.shape
# Out:
# (999, 12)

# %%
#primeiro problema é dar nomes as colunas
dataset.columns = ["Id","Score","Estado","Genero","Idade","Patrimonio","Saldo","Produtos","TemCartCredito",
                    "Ativo","Salario","Saiu"]

# %%
#visulizar
dataset.head()
# Out:
#    Id  Score Estado    Genero  Idade  Patrimonio     Saldo  Produtos  \
# 0   1    619     RS  Feminino     42           2         0         1
# 1   2    608     SC  Feminino     41           1   8380786         1
# 2   3    502     RS  Feminino     42           8   1596608         3
# 3   4    699     RS  Feminino     39           1         0         2
# 4   5    850     SC  Feminino     43           2  12551082         1
#
#    TemCartCredito  Ativo     Salario  Saiu
# 0               1      1  10134888.0     1
# 1               0      1  11254258.0     0
# 2               1      0  11393157.0     1
# 3               0      0   9382663.0     0
# 4               1      1    790841.0     0

# %%
#explorar dados categoricos
#estado
agrupado = dataset.groupby(['Estado']).size()
agrupado
# Out:
# Estado
# PR    257
# RP      1
# RS    478
# SC    258
# SP      4
# TD      1
# dtype: int64

# %%
#explorar dados categoricos
#Ativo
ativo = dataset.groupby(['Ativo']).size()
ativo
# Out:
# Ativo
# 0    490
# 1    509
# dtype: int64

# %%
agrupado.plot.bar(figsize=(15,5), rot=0, color = 'black', grid=True)
plt.title("Registros por Estado")
plt.xlabel('Estado')
plt.ylabel('Quantidade')
plt.show()

# %%
# Agrupar dados
# Saídas
saidas = dataset.groupby(['Saiu']).size()
saidas
# Out:
# Saiu
# 0    796
# 1    203
# dtype: int64

# %%
saidas.plot.bar(figsize=(10,5), rot=0, color = 'pink', grid=True)
plt.title("Registros por Ativo")
plt.xlabel('Ativo')
plt.ylabel('Quantidade')
plt.show()

# %%
#Agrupando por Gênero
#genero
agrupado = dataset.groupby(['Genero']).size()
agrupado
# Out:
# Genero
# F              2
# Fem            1
# Feminino     461
# M              6
# Masculino    521
# dtype: int64

# %%
agrupado.plot.bar(figsize=(15,5), rot=0, color = 'red', grid=True)
plt.title("Registros por Gênero")
plt.xlabel('Gênero')
plt.ylabel('Quantidade')
plt.show()

# %%
#explorar colunas numéricas
#score
dataset['Score'].describe()
# Out:
# count    999.000000
# mean     648.621622
# std       98.264219
# min      376.000000
# 25%      580.000000
# 50%      653.000000
# 75%      721.000000
# max      850.000000
# Name: Score, dtype: float64

# %%
srn.boxplot(dataset['Score']).set_title('Pontuação')
# Out:
# Text(0.5, 1.0, 'Pontuação')

# %%
# HISTOGRAMA - distribuição de frequências, é a representação gráfica em colunas ou em barras de um conjunto de dados previamente tabulado e dividido em classes uniformes ou não uniformes.
srn.distplot(dataset['Score']).set_title('Pontuação')
# Out:
# <ipython-input-15-8ae7a7d4d452>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   srn.distplot(dataset['Score']).set_title('Pontuação')
# Text(0.5, 1.0, 'Pontuação')

# %%
#idade
dataset['Idade'].describe()
# Out:
# count    999.000000
# mean      38.902903
# std       11.401912
# min      -20.000000
# 25%       32.000000
# 50%       37.000000
# 75%       44.000000
# max      140.000000
# Name: Idade, dtype: float64

# %%
srn.boxplot(dataset['Idade']).set_title('Idade')
# Out:
# Text(0.5, 1.0, 'Idade')

# %%
srn.distplot(dataset['Idade']).set_title('Idade')
# Out:
# <ipython-input-18-94ce3b36875c>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   srn.distplot(dataset['Idade']).set_title('Idade')
# Text(0.5, 1.0, 'Idade')

# %%
#saldo
dataset['Saldo'].describe()
# Out:
# count    9.990000e+02
# mean     7.164928e+06
# std      6.311840e+06
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      8.958835e+06
# 75%      1.258684e+07
# max      2.117743e+07
# Name: Saldo, dtype: float64

# %%
# Diagrama de caixa a variação de dados observados de uma variável numérica
srn.boxplot(dataset['Saldo']).set_title('Saldo')
# Out:
# Text(0.5, 1.0, 'Saldo')

# %%
srn.distplot(dataset['Saldo']).set_title('Saldo')
# Out:
# <ipython-input-21-8c7a9fcde676>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   srn.distplot(dataset['Saldo']).set_title('Saldo')
# Text(0.5, 1.0, 'Saldo')

# %%
#salário
dataset['Salario'].describe()
# Out:
# count    9.920000e+02
# mean     3.528762e+07
# std      5.305800e+08
# min      9.677000e+03
# 25%      3.029011e+06
# 50%      8.703250e+06
# 75%      1.405213e+07
# max      1.193469e+10
# Name: Salario, dtype: float64

# %%
srn.boxplot(dataset['Salario']).set_title('Salario')
# Out:
# Text(0.5, 1.0, 'Salario')

# %%
srn.distplot(dataset['Salario']).set_title('Salario')
# Out:
# <ipython-input-24-6873f43eaa22>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   srn.distplot(dataset['Salario']).set_title('Salario')
# Text(0.5, 1.0, 'Salario')

# %% [markdown]
# # **TRATAMENTO DE DADOS**

# %%
#contamos valores NAN
#genero e salário
dataset.isnull().sum()
# Out:
# Id                0
# Score             0
# Estado            0
# Genero            8
# Idade             0
# Patrimonio        0
# Saldo             0
# Produtos          0
# TemCartCredito    0
# Ativo             0
# Salario           7
# Saiu              0
# dtype: int64

# %%
#salarios
#remover nas e substiutir pela mediana
dataset['Salario'].describe()
# Out:
# count    9.920000e+02
# mean     3.528762e+07
# std      5.305800e+08
# min      9.677000e+03
# 25%      3.029011e+06
# 50%      8.703250e+06
# 75%      1.405213e+07
# max      1.193469e+10
# Name: Salario, dtype: float64

# %%
mediana = sts.median(dataset['Salario'])
mediana
# Out:
# 70518.0

# %%
#substituir NAN por mediana
dataset['Salario'].fillna(mediana, inplace=True)

# %%
#Verificamos se NAN não existem mais
dataset['Salario'].isnull().sum()
# Out:
# 0

# %%
#genero, falta de padronização e NAs
agrupado = dataset.groupby(['Genero']).size()
agrupado
# Out:
# Genero
# F              2
# Fem            1
# Feminino     461
# M              6
# Masculino    521
# dtype: int64

# %%
#total de Nas
dataset['Genero'].isnull().sum()
# Out:
# 8

# %%
#preenche NAs com Masculino (moda)
dataset['Genero'].fillna('Masculino', inplace=True)

# %%
#verificamos novamente NANs
dataset['Genero'].isnull().sum()
# Out:
# 0

# %%
#padroniza de acordo com o dominio
dataset.loc[dataset['Genero'] ==  'M', 'Genero'] = "Masculino"
dataset.loc[dataset['Genero'].isin( ['Fem','F']), 'Genero'] = "Feminino"
#visualiza o resultado
agrupado = dataset.groupby(['Genero']).size()
agrupado
# Out:
# Genero
# Feminino     464
# Masculino    535
# dtype: int64

# %%
#idades fora do dominio
dataset['Idade'].describe()
# Out:
# count    999.000000
# mean      38.902903
# std       11.401912
# min      -20.000000
# 25%       32.000000
# 50%       37.000000
# 75%       44.000000
# max      140.000000
# Name: Idade, dtype: float64

# %%
#visualizar
dataset.loc[(dataset['Idade'] <  0 )  | ( dataset['Idade'] >  100) ]
# Out:
#       Id  Score Estado     Genero  Idade  Patrimonio     Saldo  Produtos  \
# 867  869    636     RS   Feminino    -10           1  17083346         1
# 984  986    773     RS  Masculino    -20           1  12453278         2
# 990  992    655     RS  Masculino    140           5     93147         2
#
#      TemCartCredito  Ativo     Salario  Saiu
# 867               1      0  11051028.0     1
# 984               0      1   1172357.0     0
# 990               1      0   6621413.0     0

# %%
#calular a mediana
mediana = sts.median(dataset['Idade'])
mediana
# Out:
# 37

# %%
#substituir
dataset.loc[(dataset['Idade'] <  0 )  | ( dataset['Idade'] >  100), 'Idade'] = mediana

# %%
#verificamos se ainda existem idades fora do domínio
dataset.loc[(dataset['Idade'] <  0 )  | ( dataset['Idade'] >  100) ]
# Out:
# Empty DataFrame
# Columns: [Id, Score, Estado, Genero, Idade, Patrimonio, Saldo, Produtos, TemCartCredito, Ativo, Salario, Saiu]
# Index: []

# %%
#dados duplicados, buscamos pelo ID
dataset[dataset.duplicated(['Id'],keep=False)]
# Out:
#     Id  Score Estado    Genero  Idade  Patrimonio    Saldo  Produtos  \
# 80  81    665     RS  Feminino     34           1  9664554         2
# 81  81    665     RS  Feminino     34           1  9664554         2
#
#     TemCartCredito  Ativo     Salario  Saiu
# 80               0      0  17141366.0     0
# 81               0      0  17141366.0     0

# %%
#excluimso pelo ID
dataset.drop_duplicates(subset="Id", keep='first',inplace=True)
#buscamos duplicados
dataset[dataset.duplicated(['Id'],keep=False)]
# Out:
# Empty DataFrame
# Columns: [Id, Score, Estado, Genero, Idade, Patrimonio, Saldo, Produtos, TemCartCredito, Ativo, Salario, Saiu]
# Index: []

# %%
#estado foram do domínio
agrupado = dataset.groupby(['Estado']).size()
agrupado
# Out:
# Estado
# PR    257
# RP      1
# RS    477
# SC    258
# SP      4
# TD      1
# dtype: int64

# %%
#atribuomos RS (moda)
dataset.loc[dataset['Estado'].isin( ['RP','SP','TD']), 'Estado'] = "RS"
agrupado = dataset.groupby(['Estado']).size()
agrupado
# Out:
# Estado
# PR    257
# RS    483
# SC    258
# dtype: int64

# %%
#outliers em salário, vamos considerar 2 desvios padrão
desv = sts.stdev(dataset['Salario'])
desv
# Out:
# 528988918.4679201

# %%
#definir padrão como maior que 2 desvios padrão
#checamos se algum atende critério
dataset.loc[dataset['Salario'] >=  2 * desv ]
# Out:
#       Id  Score Estado     Genero  Idade  Patrimonio     Saldo  Produtos  \
# 7      8    376     PR   Feminino     29           4  11504674         4
# 116  118    668     PR   Feminino     37           6   1678644         1
# 170  172    484     RS   Feminino     29           4  13011439         1
# 230  232    673     RS  Masculino     72           1         0         2
#
#      TemCartCredito  Ativo       Salario  Saiu
# 7                 1      0  1.193469e+10     1
# 116               1      0  1.156383e+10     0
# 170               1      0  1.640179e+09     0
# 230               0      1  1.119812e+09     0

# %%
#vamos atualiar salarios para mediana, calculamos
mediana = sts.median(dataset['Salario'])
mediana
# Out:
# 8637195.5

# %%
#atribumos
dataset.loc[dataset['Salario'] >=  2 * desv, 'Salario'] = mediana
#checamos se algum atende critério
dataset.loc[dataset['Salario'] >=  2 * desv ]
# Out:
# Empty DataFrame
# Columns: [Id, Score, Estado, Genero, Idade, Patrimonio, Saldo, Produtos, TemCartCredito, Ativo, Salario, Saiu]
# Index: []

# %%
dataset.head()
# Out:
#    Id  Score Estado    Genero  Idade  Patrimonio     Saldo  Produtos  \
# 0   1    619     RS  Feminino     42           2         0         1
# 1   2    608     SC  Feminino     41           1   8380786         1
# 2   3    502     RS  Feminino     42           8   1596608         3
# 3   4    699     RS  Feminino     39           1         0         2
# 4   5    850     SC  Feminino     43           2  12551082         1
#
#    TemCartCredito  Ativo     Salario  Saiu
# 0               1      1  10134888.0     1
# 1               0      1  11254258.0     0
# 2               1      0  11393157.0     1
# 3               0      0   9382663.0     0
# 4               1      1    790841.0     0

# %%
dataset.shape
# Out:
# (998, 12)

# %% [markdown]
# # **ATIVIDADE**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as srn
import statistics  as sts

df = pd.read_csv("/content/tempo.csv", sep=";")

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Aparencia    14 non-null     object
#  1   Temperatura  14 non-null     int64
#  2   Umidade      13 non-null     float64
#  3   Vento        13 non-null     object
#  4   Jogar        14 non-null     object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 688.0+ bytes

# %%
df.isnull().sum()
# Out:
# Aparencia      0
# Temperatura    0
# Umidade        1
# Vento          1
# Jogar          0
# dtype: int64

# %%
df.head()
# Out:
#   Aparencia  Temperatura  Umidade       Vento Jogar
# 0       sol           85     85.0       FALSO   nao
# 1       sol           80     90.0  VERDADEIRO   nao
# 2   nublado           83     86.0       FALSO   sim
# 3     chuva           70      NaN       FALSO   sim
# 4     chuva           68     80.0       FALSO   sim

# %%
df.tail(5)
# Out:
#    Aparencia  Temperatura  Umidade       Vento Jogar
# 9      chuva           75    200.0         NaN   sim
# 10       sol           75     70.0  VERDADEIRO   sim
# 11   nublado           72     90.0  VERDADEIRO   sim
# 12   nublado           81     75.0       FALSO   sim
# 13     chuva           71     91.0  VERDADEIRO   nao

# %%
df.shape
# Out:
# (14, 5)

# %% [markdown]
# # **APARENCIA**

# %%
aparencia = df.groupby(['Aparencia']).size()
aparencia
# Out:
# Aparencia
# chuva      5
# menos      1
# nublado    3
# sol        5
# dtype: int64

# %%
aparencia.plot.bar(figsize=(15,5), rot=0, color = 'Blue', grid=True)
plt.title("Registros por Aparencia")
plt.xlabel('Aparencia')
plt.ylabel('Quantidade')
plt.show()

# %%
srn.boxplot(df['Aparencia']).set_title('Aparencia')
# Out:
# Text(0.5, 1.0, 'Aparencia')

# %%
aparencia = df.groupby(['Aparencia']).size()
aparencia
# Out:
# Aparencia
# chuva      5
# menos      1
# nublado    3
# sol        5
# dtype: int64

# %%
# dataset.loc[dataset['Genero'] ==  'M', 'Genero'] = "Masculino"
#dataset.loc[dataset['Genero'].isin( ['Fem','F']), 'Genero'] = "Feminino"
df.loc[df['Aparencia'] == 'menos', 'Aparencia'] = "sol"

# %%
aparencia = df.groupby(['Aparencia']).size()
aparencia
# Out:
# Aparencia
# chuva      5
# nublado    3
# sol        6
# dtype: int64

# %%
aparencia.plot.bar(figsize=(15,5), rot=0, color = 'teal', grid=True)
plt.title("Registros por Aparencia")
plt.xlabel('Aparencia')
plt.ylabel('Quantidade')
plt.show()

# %%
df.isnull().sum()
# Out:
# Aparencia      0
# Temperatura    0
# Umidade        1
# Vento          1
# Jogar          0
# dtype: int64

# %% [markdown]
# # **TEMPERATURA**

# %%
# TEMPERATURA MAXIMO DE 130º
df.groupby(['Temperatura']).size()
# Out:
# Temperatura
# 64      1
# 65      1
# 68      1
# 69      1
# 70      1
# 71      1
# 72      1
# 75      2
# 80      1
# 81      1
# 83      1
# 85      1
# 1220    1
# dtype: int64

# %%
df['Temperatura'].plot(style='-o' , linewidth=2.5, color='green', figsize=(15,5), grid=True);
plt.title('Temperatura')
plt.xlabel('Período')
plt.ylabel('Temperatura')
plt.legend(['Temperatura'], loc='upper left')
plt.show()

# %%
srn.boxplot(df['Temperatura']).set_title('Temperatura')
# Out:
# Text(0.5, 1.0, 'Temperatura')

# %%
srn.distplot(df['Temperatura']).set_title('Temperatura')
# Out:
# <ipython-input-222-ec171a6e2906>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   srn.distplot(df['Temperatura']).set_title('Temperatura')
# Text(0.5, 1.0, 'Temperatura')

# %%
medianatemp = sts.median(df['Temperatura'])
medianatemp
# Out:
# 73.5

# %%
df.loc[(df['Temperatura']>130)] = medianatemp

# %%
df.groupby(['Temperatura']).size()
# Out:
# Temperatura
# 64.0    1
# 65.0    1
# 68.0    1
# 69.0    1
# 70.0    1
# 71.0    1
# 72.0    1
# 73.5    1
# 75.0    2
# 80.0    1
# 81.0    1
# 83.0    1
# 85.0    1
# dtype: int64

# %%
df['Temperatura'].plot(style='-o' , linewidth=2.5, color='gold', figsize=(15,5), grid=True);
plt.title('Temperatura')
plt.xlabel('Período')
plt.ylabel('Temperatura')
plt.legend(['Temperatura'], loc='upper left')
plt.show()

# %%
srn.boxplot(df['Temperatura']).set_title('Temperatura')
# Out:
# Text(0.5, 1.0, 'Temperatura')

# %%
srn.distplot(df['Temperatura']).set_title('Temperatura')
# Out:
# <ipython-input-228-ec171a6e2906>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   srn.distplot(df['Temperatura']).set_title('Temperatura')
# Text(0.5, 1.0, 'Temperatura')

# %%
df.isnull().sum()
# Out:
# Aparencia      0
# Temperatura    0
# Umidade        1
# Vento          1
# Jogar          0
# dtype: int64

# %% [markdown]
# # **UMIDADE**

# %%
df.groupby(['Umidade']).size()
# Out:
# Umidade
# 65.0     1
# 70.0     3
# 75.0     1
# 80.0     1
# 85.0     1
# 86.0     1
# 90.0     2
# 91.0     1
# 95.0     1
# 200.0    1
# dtype: int64

# %%
medianaUmidade = sts.median(df['Umidade'])
medianaUmidade
# Out:
# 85.5

# %%
df.loc[(df['Umidade']>100)] = medianaUmidade

# %%
df.groupby(['Umidade']).size()
# Out:
# Umidade
# 65.0    1
# 70.0    3
# 75.0    1
# 80.0    1
# 85.0    1
# 85.5    1
# 86.0    1
# 90.0    2
# 91.0    1
# 95.0    1
# dtype: int64

# %%
df['Umidade'].plot(style='-o' , linewidth=2.5, color='deeppink', figsize=(15,5), grid=True);
plt.title('Umidade')
plt.xlabel('Período')
plt.ylabel('Umidade')
plt.legend(['Umidade'], loc='upper left')
plt.show()

# %%
mediana = sts.median(df['Umidade'])
mediana
# Out:
# 85.5

# %%
df['Umidade'].fillna(mediana, inplace=True)

# %%
df['Umidade'].plot(style='-o' , linewidth=2.5, color='darkorange', figsize=(15,5), grid=True);
plt.title('Umidade')
plt.xlabel('Período')
plt.ylabel('Umidade')
plt.legend(['Umidade'], loc='upper left')
plt.show()

# %%
df.isnull().sum()
# Out:
# Aparencia      0
# Temperatura    0
# Umidade        0
# Vento          0
# Jogar          0
# dtype: int64

# %% [markdown]
# # **VENTO**

# %%
vento = df.groupby(['Vento']).size()
vento
# Out:
# Vento
# 85.5          1
# FALSO         7
# VERDADEIRO    6
# dtype: int64

# %%
vento.plot.bar(figsize=(15,5), rot=0, color = 'black', grid=True)
plt.title("Registros por Vento")
plt.xlabel('Vento')
plt.ylabel('Quantidade')
plt.show()

# %%
#df['Vento'].fillna('FALSO', inplace=True)

# %%
# dataset.loc[(dataset['Idade'] <  0 )  | ( dataset['Idade'] >  100), 'Idade']
# dataset.loc[(dataset['Idade'] <  0 )  | ( dataset['Idade'] >  100) ]
df.loc[(df['Vento']==85.5),'Vento'] = 'FALSO'

# %%
vento = df.groupby(['Vento']).size()
vento
# Out:
# Vento
# FALSO         8
# VERDADEIRO    6
# dtype: int64

# %%
vento.plot.bar(figsize=(15,5), rot=0, color = 'indigo', grid=True)
plt.title("Registros por Vento")
plt.xlabel('Vento')
plt.ylabel('Quantidade')
plt.show()
